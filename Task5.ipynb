# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('SampleSuperstore.csv',index_col=0)
df.head()
# Out:
#                   Segment        Country             City       State  \
# Ship Mode
# Second Class     Consumer  United States        Henderson    Kentucky
# Second Class     Consumer  United States        Henderson    Kentucky
# Second Class    Corporate  United States      Los Angeles  California
# Standard Class   Consumer  United States  Fort Lauderdale     Florida
# Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#                 Postal Code Region         Category Sub-Category     Sales  \
# Ship Mode
# Second Class          42420  South        Furniture    Bookcases  261.9600
# Second Class          42420  South        Furniture       Chairs  731.9400
# Second Class          90036   West  Office Supplies       Labels   14.6200
# Standard Class        33311  South        Furniture       Tables  957.5775
# Standard Class        33311  South  Office Supplies      Storage   22.3680
#
#                 Quantity  Discount    Profit
# Ship Mode
# ...

# %%
df.isnull()
df.isnull().sum()
# Out:
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
 df.isnull().values.any()
# Out:
# False

# %%
print(df['Segment'].unique())
# Out:
# ['Consumer' 'Corporate' 'Home Office']

# %%
print(df['Country'].unique())
# Out:
# ['United States']

# %%
print(df['State'].unique())
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
sns.relplot(x='State',y ='Sales',data =df,height=8.27, aspect=30.7/8.27)

# %%
sns.relplot(x='City',y ='Sales',data = df,height=8.27, aspect=11.7/8.27)

# %%
sns.relplot(x='City',y ='Sales',data = df,height=8.27, aspect=11.7/8.27)

# %%
sns.relplot(x='Discount',y ='Sales',data = df,height=8.27, aspect=11.7/8.27)

# %% [markdown]
# ###### In this plot the products with less discount have more sales.so we have to decrease the discount giving

# %%
sns.relplot(x='Discount',y ='Profit',data = df,height=8.27, aspect=11.7/8.27)

# %% [markdown]
# ###### From this plot of discount and profit i identified that when the discount is 80% the loss is more.when the discount is 0%  there is no loss.so we have to decrease the discount

# %%
sns.relplot(x='Profit',y ='Sales',data = df,height=8.27, aspect=11.7/8.27)

# %% [markdown]
# #### Here in this plot of profit and sales the profit is less for products with price below 5000.but for products with price above 5000 should have more profit.so the number of products with rate above 5000 should have to increase.
