# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
df = pd.read_csv('iris.csv',index_col=0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
data = df.drop(['Species'],axis=1)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
wcss=[]
k_rang = 10
for i in range(1,k_rang):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
    
clusters=range(1,10)
plt.plot(clusters,wcss)
plt.title('Visualization of raw data');

# %%
plt.scatter(data.iloc[:, 0], data.iloc[:, 1])

# %%
centroids = kmeans.cluster_centers_
# Plot the clustered data
fig, ax = plt.subplots(figsize=(6, 6))

plt.scatter(data['SepalLengthCm'], data['SepalWidthCm'],c='green', label='cluster 1')

plt.scatter(data['PetalLengthCm'], data['PetalWidthCm'],
            c='blue', label='cluster 2')

plt.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=300,
            c='r', label='centroid')

# %%
 kmeans2 = KMeans(n_clusters = 2)
 kmeans2.fit(data)
 pred = data.copy()
 pred['predicted'] = kmeans2.fit_predict(data)
 pred
 plt.figure(figsize=(6, 6))

plt.scatter(pred['SepalLengthCm'], pred['SepalWidthCm'],c=pred['predicted'], label='cluster 1')
plt.title('SepalLength vs SepalWidth')
pred
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  predicted
# Id
# 1              5.1           3.5            1.4           0.2          0
# 2              4.9           3.0            1.4           0.2          0
# 3              4.7           3.2            1.3           0.2          0
# 4              4.6           3.1            1.5           0.2          0
# 5              5.0           3.6            1.4           0.2          0
# ..             ...           ...            ...           ...        ...
# 146            6.7           3.0            5.2           2.3          1
# 147            6.3           2.5            5.0           1.9          1
# 148            6.5           3.0            5.2           2.0          1
# 149            6.2           3.4            5.4           2.3          1
# 150            5.9           3.0            5.1           1.8          1
#
# [150 rows x 5 columns]

# %%
plt.scatter(pred['PetalLengthCm'], pred['PetalWidthCm'],c=pred['predicted'], label='cluster 1')
plt.title('PetalLength vs PetalWidth')
# Out:
# Text(0.5, 1.0, 'PetalLength vs PetalWidth')

# %%
 kmeans3 = KMeans(n_clusters = 3)
 kmeans3.fit(data)
 pred2 = data.copy()
 pred2['predicted'] = kmeans3.fit_predict(data)
 pred2
 plt.figure(figsize=(6, 6))

plt.scatter(pred2['SepalLengthCm'], pred2['SepalWidthCm'],c=pred2['predicted'], label='cluster 1')
plt.title('SepalLength vs SepalWidth')
# Out:
# Text(0.5, 1.0, 'SepalLength vs SepalWidth')

# %%
plt.scatter(pred2['PetalLengthCm'], pred2['PetalWidthCm'],c=pred2['predicted'], label='cluster 1')
plt.title('PetalLength vs PetalWidth')
# Out:
# Text(0.5, 1.0, 'PetalLength vs PetalWidth')
